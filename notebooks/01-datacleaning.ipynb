# %% [markdown]
# # Analysis of COVID-19 Cases in the world

# %% [markdown]
# Some requirements:
#
# - Convert data into tidy format
# - Export to normalized tables in SQLite3 Database
# - Use SQL statements (from within pandas) to retrieve data needed for each visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load raw dataset 
df = pd.read_csv("../data/raw/Data.csv")
df.head()
# Out:
#     Entity Continent  Latitude  Longitude  Average temperature per year  \
# 0  Albania    Europe     41.15      20.17                            14
# 1  Albania    Europe     41.15      20.17                            14
# 2  Albania    Europe     41.15      20.17                            14
# 3  Albania    Europe     41.15      20.17                            14
# 4  Albania    Europe     41.15      20.17                            14
#
#    Hospital beds per 1000 people  Medical doctors per 1000 people  GDP/Capita  \
# 0                           2.89                             1.29      5353.2
# 1                           2.89                             1.29      5353.2
# 2                           2.89                             1.29      5353.2
# 3                           2.89                             1.29      5353.2
# 4                           2.89                             1.29      5353.2
#
#    Population  Median age  Population aged 65 and over (%)        Date  \
# 0     2873457          38                               14  2020-02-25
# 1     2873457          38                               14  2020-02-26
# 2     2873457          38                               14  2020-02-27
# 3     2873457          38                               14  2020-02-28
# 4     2873457          38                               14  2020-02-29
#
#    Daily tests  Cases  Deaths
# 0          8.0    NaN     NaN
# 1          5.0    NaN     NaN
# 2          4.0    NaN     NaN
# 3          1.0    NaN     NaN
# 4          8.0    NaN     NaN

# %%
# Categories
df.columns
# Out:
# Index(['Entity', 'Continent', 'Latitude', 'Longitude',
#        'Average temperature per year', 'Hospital beds per 1000 people',
#        'Medical doctors per 1000 people', 'GDP/Capita', 'Population',
#        'Median age', 'Population aged 65 and over (%)', 'Date', 'Daily tests',
#        'Cases', 'Deaths'],
#       dtype='object')

# %% [markdown]
# Since the column name "Entity" is misleading, I will rename it to be country, but first I will check if all the data in that column is actually a country name.

# %%
country_list = set(df['Entity'])
set(df['Entity'])
# Out:
# {'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Canada',
#  'Cape Verde',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kuwait',
#  'Latvia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Malta',
#  'Mauritania',
#  'Mexico',
#  'Mongolia',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'New Zealand',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'South Korea',
#  'Sri Lanka',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Vietnam',
#  'Zambia',
#  'Zimbabwe'}

# %%
new_df = df.rename(columns={'Entity': 'Country'})

# %%
# Shift (Country, Continent, Date) to the front

shift_keys = ['Country', 'Continent', 'Date']
new_df = new_df[[key for key in shift_keys if key in new_df] + [i for i in new_df if i not in shift_keys]]
new_df
# Out:
#         Country Continent        Date  Latitude  Longitude  \
# 0       Albania    Europe  2020-02-25     41.15      20.17
# 1       Albania    Europe  2020-02-26     41.15      20.17
# 2       Albania    Europe  2020-02-27     41.15      20.17
# 3       Albania    Europe  2020-02-28     41.15      20.17
# 4       Albania    Europe  2020-02-29     41.15      20.17
# ...         ...       ...         ...       ...        ...
# 38467  Zimbabwe    Africa  2021-02-24    -19.02      29.15
# 38468  Zimbabwe    Africa  2021-02-25    -19.02      29.15
# 38469  Zimbabwe    Africa  2021-02-26    -19.02      29.15
# 38470  Zimbabwe    Africa  2021-02-27    -19.02      29.15
# 38471  Zimbabwe    Africa  2021-02-28    -19.02      29.15
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 0                                14                           2.89
# 1                                14                           2.89
# 2                                14                           2.89
# 3                                14                           2.89
# 4                                14                           2.89
# ...                             ...                            ...
# 38467                            20                           1.70
# 38468                            20                           1.70
# 38469                            20                           1.70
# 38470                            20                           1.70
# 38471                            20                           1.70
#
#        Medical doctors per 1000 people  GDP/Capita  Population  Median age  \
# 0                                 1.29      5353.2     2873457          38
# 1                                 1.29      5353.2     2873457          38
# 2                                 1.29      5353.2     2873457          38
# 3                                 1.29      5353.2     2873457          38
# 4                                 1.29      5353.2     2873457          38
# ...                                ...         ...         ...         ...
# 38467                             0.08      1464.0    16529904          19
# 38468                             0.08      1464.0    16529904          19
# 38469                             0.08      1464.0    16529904          19
# 38470                             0.08      1464.0    16529904          19
# 38471                             0.08      1464.0    16529904          19
#
#        Population aged 65 and over (%)  Daily tests    Cases  Deaths
# 0                                   14          8.0      NaN     NaN
# 1                                   14          5.0      NaN     NaN
# 2                                   14          4.0      NaN     NaN
# 3                                   14          1.0      NaN     NaN
# 4                                   14          8.0      NaN     NaN
# ...                                ...          ...      ...     ...
# 38467                                3       1804.0  35960.0  1456.0
# 38468                                3       2965.0  35994.0  1458.0
# 38469                                3          NaN  36044.0  1463.0
# 38470                                3          NaN  36058.0  1463.0
# 38471                                3          NaN  36089.0  1463.0
#
# [38472 rows x 15 columns]

# %%
# Replace NaN values in table
new_df = new_df.fillna(0)
new_df
# Out:
#         Country Continent        Date  Latitude  Longitude  \
# 0       Albania    Europe  2020-02-25     41.15      20.17
# 1       Albania    Europe  2020-02-26     41.15      20.17
# 2       Albania    Europe  2020-02-27     41.15      20.17
# 3       Albania    Europe  2020-02-28     41.15      20.17
# 4       Albania    Europe  2020-02-29     41.15      20.17
# ...         ...       ...         ...       ...        ...
# 38467  Zimbabwe    Africa  2021-02-24    -19.02      29.15
# 38468  Zimbabwe    Africa  2021-02-25    -19.02      29.15
# 38469  Zimbabwe    Africa  2021-02-26    -19.02      29.15
# 38470  Zimbabwe    Africa  2021-02-27    -19.02      29.15
# 38471  Zimbabwe    Africa  2021-02-28    -19.02      29.15
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 0                                14                           2.89
# 1                                14                           2.89
# 2                                14                           2.89
# 3                                14                           2.89
# 4                                14                           2.89
# ...                             ...                            ...
# 38467                            20                           1.70
# 38468                            20                           1.70
# 38469                            20                           1.70
# 38470                            20                           1.70
# 38471                            20                           1.70
#
#        Medical doctors per 1000 people  GDP/Capita  Population  Median age  \
# 0                                 1.29      5353.2     2873457          38
# 1                                 1.29      5353.2     2873457          38
# 2                                 1.29      5353.2     2873457          38
# 3                                 1.29      5353.2     2873457          38
# 4                                 1.29      5353.2     2873457          38
# ...                                ...         ...         ...         ...
# 38467                             0.08      1464.0    16529904          19
# 38468                             0.08      1464.0    16529904          19
# 38469                             0.08      1464.0    16529904          19
# 38470                             0.08      1464.0    16529904          19
# 38471                             0.08      1464.0    16529904          19
#
#        Population aged 65 and over (%)  Daily tests    Cases  Deaths
# 0                                   14          8.0      0.0     0.0
# 1                                   14          5.0      0.0     0.0
# 2                                   14          4.0      0.0     0.0
# 3                                   14          1.0      0.0     0.0
# 4                                   14          8.0      0.0     0.0
# ...                                ...          ...      ...     ...
# 38467                                3       1804.0  35960.0  1456.0
# 38468                                3       2965.0  35994.0  1458.0
# 38469                                3          0.0  36044.0  1463.0
# 38470                                3          0.0  36058.0  1463.0
# 38471                                3          0.0  36089.0  1463.0
#
# [38472 rows x 15 columns]

# %%
# Compare statistics of countries
country_df = new_df.groupby(by='Country').mean(numeric_only = True)
country_df
# Out:
#                Latitude  Longitude  Average temperature per year  \
# Country
# Albania           41.15      20.17                          14.0
# Algeria           28.03       1.66                          25.0
# Argentina        -38.42     -63.62                          14.0
# Armenia           40.07      45.04                          11.0
# Australia        -25.27     133.78                          22.0
# ...                 ...        ...                           ...
# United States     37.09     -95.71                          11.0
# Uruguay          -32.52     -55.77                          16.0
# Vietnam           14.06     108.28                          25.0
# Zambia           -13.13      27.85                          21.0
# Zimbabwe         -19.02      29.15                          20.0
#
#                Hospital beds per 1000 people  Medical doctors per 1000 people  \
# Country
# Albania                                 2.89                             1.29
# Algeria                                 1.90                             1.83
# Argentina                               5.00                             3.91
# Armenia                                 4.20                             2.80
# Australia                               3.84                             3.50
# ...                                      ...                              ...
# United States                           2.77                             2.57
# Uruguay                                 2.80                             3.74
# Vietnam                                 2.60                             0.82
# Zambia                                  2.00                             0.09
# Zimbabwe                                1.70                             0.08
#
#                GDP/Capita   Population  Median age  \
# Country
# Albania            5353.2    2873457.0        38.0
# Algeria            3974.0   41318142.0        29.0
# Argentina          9912.3   44271041.0        31.0
# Armenia            4622.7    2930450.0        35.0
# Australia         55060.3   24598933.0        37.0
# ...                   ...          ...         ...
# United States     65297.5  325719178.0        38.0
# Uruguay           16190.1    3456750.0        35.0
# Vietnam            2715.3   95540800.0        32.0
# Zambia             1305.1   17094130.0        17.0
# Zimbabwe           1464.0   16529904.0        19.0
#
#                Population aged 65 and over (%)    Daily tests         Cases  \
# Country
# Albania                                   14.0    1170.264865  2.277428e+04
# Algeria                                    6.0       8.378378  4.565502e+04
# Argentina                                 11.0   15085.977723  6.445117e+05
# Armenia                                   11.0     273.035616  6.676794e+04
# Australia                                 16.0   23341.352500  1.697356e+04
# ...                                        ...            ...           ...
# United States                             16.0  812883.797030  7.991328e+06
# Uruguay                                   15.0    2279.059490  8.799329e+03
# Vietnam                                    7.0     828.017370  8.168933e+02
# Zambia                                     2.0    3000.876437  1.571817e+04
# Zimbabwe                                   3.0    1062.517341  8.981931e+03
#
#                       Deaths
# Country
# Albania           464.572973
# Algeria          1480.656757
# Argentina       16392.730198
# Armenia          1174.460274
# Australia         466.437500
# ...                      ...
# United States  180869.995050
# Uruguay           104.288952
# Vietnam            17.302730
# Zambia            277.178161
# Zimbabwe          284.531792
#
# [104 rows x 12 columns]

# %%
# Compare statistics of continents
continent_df = new_df.groupby(by = 'Continent').mean(numeric_only = True)
continent_df
# Out:
#                 Latitude   Longitude  Average temperature per year  \
# Continent
# Africa          3.551885   15.747523                     23.348312
# Asia           26.648408   78.826848                     20.860524
# Europe         48.987978   15.519167                     10.086875
# North America  21.854118  -85.625612                     21.450269
# Oceania       -27.652714  161.632464                     19.341071
# South America -19.400020  -67.570861                     18.278689
#
#                Hospital beds per 1000 people  Medical doctors per 1000 people  \
# Continent
# Africa                              1.362825                         0.447113
# Asia                                3.075836                         1.657297
# Europe                              4.928825                         3.420736
# North America                       2.127629                         2.174985
# Oceania                             2.951580                         2.517446
# South America                       2.182247                         1.904809
#
#                  GDP/Capita    Population  Median age  \
# Continent
# Africa          2373.875488  3.465669e+07   21.680748
# Asia           14729.942616  1.090739e+08   31.011977
# Europe         33769.866981  1.365762e+07   41.531816
# North America  18735.789637  5.445039e+07   32.438021
# Oceania        35401.060268  1.064159e+07   34.163393
# South America   8725.912637  2.305394e+07   30.153005
#
#                Population aged 65 and over (%)   Daily tests          Cases  \
# Continent
# Africa                                3.783802   3104.280237   56471.208664
# Asia                                  7.025745  45337.286213  350663.834214
# Europe                               18.220805  24512.868427  175556.997074
# North America                        10.341744  87639.333170  910815.109750
# Oceania                              12.533036   9669.627679    6613.240179
# South America                         9.274932  10908.385929  334457.302937
#
#                      Deaths
# Continent
# Africa          1269.688013
# Asia            6149.283761
# Europe          5883.651686
# North America  25423.497060
# Oceania          173.610714
# South America  10599.414959

# %% [markdown]
# ## Normalizing Data
#
# 1NF - Remove duplicates
# 2NF - Remove partial dependency (i.e. no candidate/super keys)
# 3NF - Remove transistive dependency (i.e. no attributes are determined by another attribute other than primary key)

# %%
# Remove any duplicates in dataframe (1NF)
new_df = new_df.drop_duplicates()
new_df
# Out:
#         Country Continent        Date  Latitude  Longitude  \
# 0       Albania    Europe  2020-02-25     41.15      20.17
# 1       Albania    Europe  2020-02-26     41.15      20.17
# 2       Albania    Europe  2020-02-27     41.15      20.17
# 3       Albania    Europe  2020-02-28     41.15      20.17
# 4       Albania    Europe  2020-02-29     41.15      20.17
# ...         ...       ...         ...       ...        ...
# 38467  Zimbabwe    Africa  2021-02-24    -19.02      29.15
# 38468  Zimbabwe    Africa  2021-02-25    -19.02      29.15
# 38469  Zimbabwe    Africa  2021-02-26    -19.02      29.15
# 38470  Zimbabwe    Africa  2021-02-27    -19.02      29.15
# 38471  Zimbabwe    Africa  2021-02-28    -19.02      29.15
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 0                                14                           2.89
# 1                                14                           2.89
# 2                                14                           2.89
# 3                                14                           2.89
# 4                                14                           2.89
# ...                             ...                            ...
# 38467                            20                           1.70
# 38468                            20                           1.70
# 38469                            20                           1.70
# 38470                            20                           1.70
# 38471                            20                           1.70
#
#        Medical doctors per 1000 people  GDP/Capita  Population  Median age  \
# 0                                 1.29      5353.2     2873457          38
# 1                                 1.29      5353.2     2873457          38
# 2                                 1.29      5353.2     2873457          38
# 3                                 1.29      5353.2     2873457          38
# 4                                 1.29      5353.2     2873457          38
# ...                                ...         ...         ...         ...
# 38467                             0.08      1464.0    16529904          19
# 38468                             0.08      1464.0    16529904          19
# 38469                             0.08      1464.0    16529904          19
# 38470                             0.08      1464.0    16529904          19
# 38471                             0.08      1464.0    16529904          19
#
#        Population aged 65 and over (%)  Daily tests    Cases  Deaths
# 0                                   14          8.0      0.0     0.0
# 1                                   14          5.0      0.0     0.0
# 2                                   14          4.0      0.0     0.0
# 3                                   14          1.0      0.0     0.0
# 4                                   14          8.0      0.0     0.0
# ...                                ...          ...      ...     ...
# 38467                                3       1804.0  35960.0  1456.0
# 38468                                3       2965.0  35994.0  1458.0
# 38469                                3          0.0  36044.0  1463.0
# 38470                                3          0.0  36058.0  1463.0
# 38471                                3          0.0  36089.0  1463.0
#
# [38472 rows x 15 columns]

# %%
# 2NF Remove partial dependency (no candidate/super keys)
## Candidate keys are Continent/Latitude/Longtitude; {Latitude + Longtitude} is a composite key as you can determine the country using these two keys

candidate_keys = ['Country', 'Latitude', 'Longitude']
country_details = new_df[[key for key in candidate_keys]].drop_duplicates().reset_index(drop=True)
country_details
# Out:
#            Country  Latitude  Longitude
# 0          Albania     41.15      20.17
# 1          Algeria     28.03       1.66
# 2        Argentina    -38.42     -63.62
# 3          Armenia     40.07      45.04
# 4        Australia    -25.27     133.78
# ..             ...       ...        ...
# 99   United States     37.09     -95.71
# 100        Uruguay    -32.52     -55.77
# 101        Vietnam     14.06     108.28
# 102         Zambia    -13.13      27.85
# 103       Zimbabwe    -19.02      29.15
#
# [104 rows x 3 columns]

# %%
second_normalized_table = new_df[['Country'] + [i for i in new_df if i not in candidate_keys]]
second_normalized_table
# Out:
#         Country Continent        Date  Average temperature per year  \
# 0       Albania    Europe  2020-02-25                            14
# 1       Albania    Europe  2020-02-26                            14
# 2       Albania    Europe  2020-02-27                            14
# 3       Albania    Europe  2020-02-28                            14
# 4       Albania    Europe  2020-02-29                            14
# ...         ...       ...         ...                           ...
# 38467  Zimbabwe    Africa  2021-02-24                            20
# 38468  Zimbabwe    Africa  2021-02-25                            20
# 38469  Zimbabwe    Africa  2021-02-26                            20
# 38470  Zimbabwe    Africa  2021-02-27                            20
# 38471  Zimbabwe    Africa  2021-02-28                            20
#
#        Hospital beds per 1000 people  Medical doctors per 1000 people  \
# 0                               2.89                             1.29
# 1                               2.89                             1.29
# 2                               2.89                             1.29
# 3                               2.89                             1.29
# 4                               2.89                             1.29
# ...                              ...                              ...
# 38467                           1.70                             0.08
# 38468                           1.70                             0.08
# 38469                           1.70                             0.08
# 38470                           1.70                             0.08
# 38471                           1.70                             0.08
#
#        GDP/Capita  Population  Median age  Population aged 65 and over (%)  \
# 0          5353.2     2873457          38                               14
# 1          5353.2     2873457          38                               14
# 2          5353.2     2873457          38                               14
# 3          5353.2     2873457          38                               14
# 4          5353.2     2873457          38                               14
# ...           ...         ...         ...                              ...
# 38467      1464.0    16529904          19                                3
# 38468      1464.0    16529904          19                                3
# 38469      1464.0    16529904          19                                3
# 38470      1464.0    16529904          19                                3
# 38471      1464.0    16529904          19                                3
#
#        Daily tests    Cases  Deaths
# 0              8.0      0.0     0.0
# 1              5.0      0.0     0.0
# 2              4.0      0.0     0.0
# 3              1.0      0.0     0.0
# 4              8.0      0.0     0.0
# ...            ...      ...     ...
# 38467       1804.0  35960.0  1456.0
# 38468       2965.0  35994.0  1458.0
# 38469          0.0  36044.0  1463.0
# 38470          0.0  36058.0  1463.0
# 38471          0.0  36089.0  1463.0
#
# [38472 rows x 13 columns]

# %%
# 3NF Remove transistive dependency (no attribute is determined by another attribute other than primary key)
## Country -> Latitude, Longtitude, Average temperature per year, Hospital beds per 1000 people, Medical doctors per 1000 people, GDP/Capita, Population, Median age, Population aged 65 and over (%)
final_normalized = second_normalized_table.copy()
final_normalized
# Out:
#         Country Continent        Date  Average temperature per year  \
# 0       Albania    Europe  2020-02-25                            14
# 1       Albania    Europe  2020-02-26                            14
# 2       Albania    Europe  2020-02-27                            14
# 3       Albania    Europe  2020-02-28                            14
# 4       Albania    Europe  2020-02-29                            14
# ...         ...       ...         ...                           ...
# 38467  Zimbabwe    Africa  2021-02-24                            20
# 38468  Zimbabwe    Africa  2021-02-25                            20
# 38469  Zimbabwe    Africa  2021-02-26                            20
# 38470  Zimbabwe    Africa  2021-02-27                            20
# 38471  Zimbabwe    Africa  2021-02-28                            20
#
#        Hospital beds per 1000 people  Medical doctors per 1000 people  \
# 0                               2.89                             1.29
# 1                               2.89                             1.29
# 2                               2.89                             1.29
# 3                               2.89                             1.29
# 4                               2.89                             1.29
# ...                              ...                              ...
# 38467                           1.70                             0.08
# 38468                           1.70                             0.08
# 38469                           1.70                             0.08
# 38470                           1.70                             0.08
# 38471                           1.70                             0.08
#
#        GDP/Capita  Population  Median age  Population aged 65 and over (%)  \
# 0          5353.2     2873457          38                               14
# 1          5353.2     2873457          38                               14
# 2          5353.2     2873457          38                               14
# 3          5353.2     2873457          38                               14
# 4          5353.2     2873457          38                               14
# ...           ...         ...         ...                              ...
# 38467      1464.0    16529904          19                                3
# 38468      1464.0    16529904          19                                3
# 38469      1464.0    16529904          19                                3
# 38470      1464.0    16529904          19                                3
# 38471      1464.0    16529904          19                                3
#
#        Daily tests    Cases  Deaths
# 0              8.0      0.0     0.0
# 1              5.0      0.0     0.0
# 2              4.0      0.0     0.0
# 3              1.0      0.0     0.0
# 4              8.0      0.0     0.0
# ...            ...      ...     ...
# 38467       1804.0  35960.0  1456.0
# 38468       2965.0  35994.0  1458.0
# 38469          0.0  36044.0  1463.0
# 38470          0.0  36058.0  1463.0
# 38471          0.0  36089.0  1463.0
#
# [38472 rows x 13 columns]

# %%
# Save cleaned data into data/clean folder

final_normalized.to_csv("../data/clean/CleanData.csv")
country_details.to_csv("../data/clean/CountryDetails.csv")
